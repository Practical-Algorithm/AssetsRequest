# %%
import os
import notion

# %%
DISCORD_WEBHOOK = os.getenv('DISCORD_WEBHOOK')

# %%
posts = notion.get_posts()
# Out:
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# INFO:notion_client:POST https://api.notion.com/v1/databases/b503962bc98f426e8e134040306a6f2f/query
# ...

# %%
print(posts)
print(len(posts))
# Out:
# [{'id': '1789a6f3-1b84-80cc-873a-f10908d730f6', 'link': 'https://www.notion.so/DP-Recurrence-Relation-1789a6f31b8480cc873af10908d730f6', 'title': 'DP: Recurrence Relation'}, {'id': '1779a6f3-1b84-8042-9677-c4c5708b473d', 'link': 'https://www.notion.so/TUMSO-Contest-1779a6f31b8480429677c4c5708b473d', 'title': 'TUMSO Contest'}, {'id': '1729a6f3-1b84-8024-a7ea-d02b30be9098', 'link': 'https://www.notion.so/CP-Slay-the-Dragon-1729a6f31b848024a7ead02b30be9098', 'title': 'CP: Slay the Dragon'}, {'id': '16f9a6f3-1b84-8089-89b8-cfc5b8e53122', 'link': 'https://www.notion.so/Parity-point-check-16f9a6f31b84808989b8cfc5b8e53122', 'title': 'Parity point check'}, {'id': '1649a6f3-1b84-80ec-9dba-f9816f03535a', 'link': 'https://www.notion.so/Update-LikeButton-1649a6f31b8480ec9dbaf9816f03535a', 'title': 'Update: LikeButton'}, {'id': '15c9a6f3-1b84-805c-994f-db04814512a8', 'link': 'https://www.notion.so/DP-Short-Post-15c9a6f31b84805c994fdb04814512a8', 'title': 'DP: Short Post'}, {'id': '1569a6f3-1b84-8
# ...
